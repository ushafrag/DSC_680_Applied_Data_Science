# %%
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt

df = pd.read_csv("C:/Users/BALAM/Downloads/amazon.csv/amazon.csv")

print(df.head())
print(df.describe()) 
print(df.info()) 
df.head()
df.shape
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             ₹399
# 1  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 2  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 3  Computers&Accessories|Accessories&Peripherals|...             ₹329
# 4  Computers&Accessories|Accessories&Peripherals|...             ₹154
#
#   actual_price discount_percentage rating rating_count  \
# 0       ₹1,099                 64%    4.2       24,269
# ...

# %%
plt.figure(figsize=(10, 6))
plt.scatter(df['product_id'], df['rating'])
plt.xlabel('product_id')
plt.ylabel('rating')
plt.title('Scatter Plot')
plt.show()

# %%
df.iloc[0:5,:]
df.iloc[5:,:5]
df.iloc[:,:]
# Out:
#       product_id                                       product_name  \
# 0     B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1     B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2     B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3     B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4     B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
# ...          ...                                                ...
# 1460  B08L7J3T31  Noir Aqua - 5pcs PP Spun Filter + 1 Spanner | ...
# 1461  B01M6453MB  Prestige Delight PRWO Electric Rice Cooker (1 ...
# 1462  B009P2LIL4  Bajaj Majesty RX10 2000 Watts Heat Convector R...
# 1463  B00J5DYCCA  Havells Ventil Air DSP 230mm Exhaust Fan (Pist...
# 1464  B01486F4G6  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...
#
#                                                category discounted_price  \
# 0     Computers&Accessories|Accessories&Peripherals|...             ₹399
# ...

# %%
# prints from 5th rows onwards 
df.loc[5:,:]

# prints first five rows 
df.loc[0:5,:]
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
# 5  B08Y1TFSP6  pTron Solero TB301 3A Type-C Data and Fast Cha...
#
#                                             category discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             ₹399
# 1  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 2  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 3  Computers&Accessories|Accessories&Peripherals|...             ₹329
# 4  Computers&Accessories|Accessories&Peripherals|...             ₹154
# 5  Computers&Accessories|Accessories&Peripherals|...             ₹149
#
# ...

# %%
df.describe()
# Out:
#         product_id                                       product_name  \
# count         1465                                               1465
# unique        1351                                               1337
# top     B08WRWPM22  Fire-Boltt Ninja Call Pro Plus 1.83" Smart Wat...
# freq             3                                                  5
#
#                                                  category discounted_price  \
# count                                                1465             1465
# unique                                                211              550
# top     Computers&Accessories|Accessories&Peripherals|...             ₹199
# freq                                                  233               53
#
#        actual_price discount_percentage rating rating_count  \
# count          1465                1465   1465         1463
# unique          449                  92     28         1143
# ...

# %%
import matplotlib.pyplot as plt
df['rating'].hist(bins=10)
plt.title('Histogram of Product and its rating')
plt.xlabel('product_name')
plt.ylabel('rating')
plt.show()

# %%
import pandas as pd
df['rating'] = pd.to_numeric(df['rating'], errors='coerce')
df.boxplot(column='rating', by='user_name', grid=False)

# Show the plot
plt.title('Boxplot of Ratings by User Name')
plt.suptitle('')  
plt.xlabel('User Name')
plt.ylabel('Rating')
plt.xticks(rotation=45)  
plt.tight_layout()      
plt.show()
# Out:
# C:\Users\BALAM\AppData\Local\Temp\ipykernel_932\282873524.py:11: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()       # Adjust layout to avoid clipping

# %%
df = pd.read_csv('C:/Users/BALAM/Downloads/amazon.csv/amazon.csv', nrows=3)
df
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
#
#                                             category discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             ₹399
# 1  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 2  Computers&Accessories|Accessories&Peripherals|...             ₹199
#
#   actual_price discount_percentage  rating rating_count  \
# 0       ₹1,099                 64%     4.2       24,269
# 1         ₹349                 43%     4.0       43,994
# 2       ₹1,899                 90%     3.9        7,928
#
#                                        about_product  \
# 0  High Compatibility : Compatible With iPhone 12...
# 1  Compatible with all Type C enabled devices, be...
# ...

# %%
df= pd.read_csv("C:/Users/BALAM/Downloads/amazon.csv/amazon.csv")
print("Previous Dataset: ")
print(df)
# using skiprows
df = pd.read_csv("C:/Users/BALAM/Downloads/amazon.csv/amazon.csv", skiprows = [4,5])
print("Dataset After skipping rows: ")
print(df)
# Out:
# Previous Dataset:
#       product_id                                       product_name  \
# 0     B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1     B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2     B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3     B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4     B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
# ...          ...                                                ...
# 1460  B08L7J3T31  Noir Aqua - 5pcs PP Spun Filter + 1 Spanner | ...
# 1461  B01M6453MB  Prestige Delight PRWO Electric Rice Cooker (1 ...
# 1462  B009P2LIL4  Bajaj Majesty RX10 2000 Watts Heat Convector R...
# 1463  B00J5DYCCA  Havells Ventil Air DSP 230mm Exhaust Fan (Pist...
# 1464  B01486F4G6  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...
#
#                                                category discounted_price  \
# ...

# %%
df= pd.read_csv("C:/Users/BALAM/Downloads/amazon.csv/amazon.csv")
# Plotting Products and rating in Amazon
sns.lineplot(df,x=df["product_id"],y=df["rating"])

# Adding Labels
plt.title("Products and rating in Amazon")
plt.xlabel("product_id")
plt.ylabel("rating")
# Out:
# Text(0, 0.5, 'rating')

# %%
df= pd.read_csv("C:/Users/BALAM/Downloads/amazon.csv/amazon.csv")
pd.value_counts(df['discount_percentage']).plot(kind='pie' , autopct = '%1.0f%%')
# Out:
# C:\Users\BALAM\AppData\Local\Temp\ipykernel_16908\3662899475.py:2: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pd.value_counts(df['discount_percentage']).plot(kind='pie' , autopct = '%1.0f%%')
# <Axes: ylabel='count'>

# %%
fig , ax1 = plt.subplots()
df= pd.read_csv("C:/Users/BALAM/Downloads/amazon.csv/amazon.csv")
ax2 = ax1.twinx() 

ax1.bar(df['product_id'] , df['actual_price'] )
# Out:
# <BarContainer object of 1465 artists>

# %%
# Top 2 most sold products-
data['category'].value_counts()[0:5].index

most_sold_product = data['category'].value_counts()[0:5].index
most_sold_product_df = data[data['category'].isin(most_sold_product)]
most_sold_product_df.head(5)
most_sold_product_df.groupby('category').size()
# Out:
# category
# Computers&Accessories|Accessories&Peripherals|Cables&Accessories|Cables|USBCables    233
# Electronics|Headphones,Earbuds&Accessories|Headphones|In-Ear                          52
# Electronics|HomeTheater,TV&Video|Televisions|SmartTelevisions                         63
# Electronics|Mobiles&Accessories|Smartphones&BasicMobiles|Smartphones                  68
# Electronics|WearableTechnology|SmartWatches                                           76
# dtype: int64
