# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
import pandas as pd

# Load the childcare costs data
Uber_rides = pd.read_csv("C:/Users/BALAM/Downloads/ncr_ride_bookings.csv")

# Display the first few rows of each dataset
print(Uber_rides.head())
# Out:
#          Date      Time    Booking ID   Booking Status   Customer ID  \
# 0   3/23/2024  12:29:38  "CNR5884300"  No Driver Found  "CID1982111"
# 1  11/29/2024  18:01:39  "CNR1326809"       Incomplete  "CID4604802"
# 2   8/23/2024   8:56:10  "CNR8494506"        Completed  "CID9202816"
# 3  10/21/2024  17:17:25  "CNR8906825"        Completed  "CID2610914"
# 4   9/16/2024  22:08:00  "CNR1950162"        Completed  "CID9933542"
#
#     Vehicle Type      Pickup Location      Drop Location  Avg VTAT  Avg CTAT  \
# 0          eBike          Palam Vihar            Jhilmil       NaN       NaN
# 1       Go Sedan        Shastri Nagar  Gurgaon Sector 56       4.9      14.0
# 2           Auto              Khandsa      Malviya Nagar      13.4      25.8
# 3  Premier Sedan  Central Secretariat           Inderlok      13.1      28.5
# 4           Bike     Ghitorni Village        Khan Market       5.3      19.6
#
#    ...  Reason for cancelling by Customer Cancelled Rides by Driver  \
# ...

# %%
# Load the childcare costs data
Uber_rides = pd.read_csv("C:/Users/BALAM/Downloads/ncr_ride_bookings.csv")

Uber_rides.head()
# Out:
#          Date      Time    Booking ID   Booking Status   Customer ID  \
# 0   3/23/2024  12:29:38  "CNR5884300"  No Driver Found  "CID1982111"
# 1  11/29/2024  18:01:39  "CNR1326809"       Incomplete  "CID4604802"
# 2   8/23/2024   8:56:10  "CNR8494506"        Completed  "CID9202816"
# 3  10/21/2024  17:17:25  "CNR8906825"        Completed  "CID2610914"
# 4   9/16/2024  22:08:00  "CNR1950162"        Completed  "CID9933542"
#
#     Vehicle Type      Pickup Location      Drop Location  Avg VTAT  Avg CTAT  \
# 0          eBike          Palam Vihar            Jhilmil       NaN       NaN
# 1       Go Sedan        Shastri Nagar  Gurgaon Sector 56       4.9      14.0
# 2           Auto              Khandsa      Malviya Nagar      13.4      25.8
# 3  Premier Sedan  Central Secretariat           Inderlok      13.1      28.5
# 4           Bike     Ghitorni Village        Khan Market       5.3      19.6
#
#    ...  Reason for cancelling by Customer Cancelled Rides by Driver  \
# ...

# %%
Uber_rides.shape
# Out:
# (150000, 21)

# %%
## Rounding the column average school rating to 2 decimal places
Uber_rides['Driver Ratings'] = Uber_rides['Driver Ratings'].round(2)
print(Uber_rides['Driver Ratings'])
# Out:
# 0         NaN
# 1         NaN
# 2         4.9
# 3         4.6
# 4         4.1
#          ...
# 149995    3.7
# 149996    4.8
# 149997    3.9
# 149998    4.1
# 149999    4.6
# Name: Driver Ratings, Length: 150000, dtype: float64

# %%
Uber_rides.hist(column='Driver Ratings', figsize = (16,10),edgecolor='black')
plt.xlabel('Average Driver Ratings')
plt.ylabel('Uber Rides')
plt.title('Driver Rating Distribution')
# Out:
# Text(0.5, 1.0, 'Driver Rating Distribution')

# %%
## Histogram function on Booking Value
Uber_rides.hist(column='Booking Value', figsize = (16,10),edgecolor='black')
plt.xlabel('Booking Value')
plt.ylabel('rides')
plt.title('Booking Value Distribution')
# Out:
# Text(0.5, 1.0, 'Booking Value Distribution')

# %%
mean_rating = Uber_rides.groupby('Booking ID')[['Driver Ratings']].mean()
# Highest rated movies
highest_rated = mean_rating['Driver Ratings'].idxmax()
Uber_rides.loc[Uber_rides['Booking ID'] ==highest_rated]
# Out:
#              Date      Time    Booking ID Booking Status   Customer ID  \
# 89433  11/14/2024  12:28:23  "CNR1002930"      Completed  "CID5511829"
#
#       Vehicle Type Pickup Location Drop Location  Avg VTAT  Avg CTAT  ...  \
# 89433     Go Sedan      Delhi Gate   Jama Masjid       6.7      17.3  ...
#
#        Reason for cancelling by Customer Cancelled Rides by Driver  \
# 89433                                NaN                       NaN
#
#        Driver Cancellation Reason Incomplete Rides  Incomplete Rides Reason  \
# 89433                         NaN              NaN                      NaN
#
#       Booking Value  Ride Distance  Driver Ratings  Customer Rating  \
# 89433         437.0          48.87             5.0              3.9
#
#        Payment Method
# 89433            Cash
#
# [1 rows x 21 columns]

# %%
# Find Lowest and Highest rated Drivers:
## Calculate the count of movies watched by user frequency
mean_rating = Uber_rides.groupby('Booking ID')[['Driver Ratings']].mean()

# Lowest rated Driver
lowest_rated = mean_rating['Driver Ratings'].idxmin()
Uber_rides.loc[Uber_rides['Booking ID'] == lowest_rated]
# Out:
#              Date     Time    Booking ID Booking Status   Customer ID  \
# 141009  8/17/2024  6:22:23  "CNR1007726"      Completed  "CID4098276"
#
#          Vehicle Type Pickup Location Drop Location  Avg VTAT  Avg CTAT  ...  \
# 141009  Premier Sedan    Nirman Vihar   Narsinghpur      14.3      27.5  ...
#
#         Reason for cancelling by Customer Cancelled Rides by Driver  \
# 141009                                NaN                       NaN
#
#         Driver Cancellation Reason Incomplete Rides  Incomplete Rides Reason  \
# 141009                         NaN              NaN                      NaN
#
#        Booking Value  Ride Distance  Driver Ratings  Customer Rating  \
# 141009         385.0          38.23             3.0              4.4
#
#         Payment Method
# 141009             UPI
#
# [1 rows x 21 columns]

# %%
   # Histogram
df = pd.read_csv("C:/Users/BALAM/Downloads/ncr_ride_bookings.csv")
plt.figure(figsize=(10, 6))
sns.histplot(data=df, x='Customer Rating', kde=True)
plt.title('Histogram of Customer Rating')
plt.xlabel('Customer Rating')
plt.ylabel('Frequency')
plt.show()

# %%
   # Histogram
df = pd.read_csv("C:/Users/BALAM/Downloads/ncr_ride_bookings.csv")
plt.figure(figsize=(10, 6))
sns.histplot(data=df, x='Driver Ratings', kde=True)
plt.title('Histogram of Driver Rating')
plt.xlabel('Driver Ratings')
plt.ylabel('Frequency')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

    # Pair plot for visualizing relationships between multiple numerical columns
sns.pairplot(df[['Avg VTAT', 'Avg CTAT', 'Booking Value']])
plt.show()

    # Heatmap for correlation matrix
correlation_matrix = df.corr(numeric_only=True)
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %%
df['Avg VTAT'].value_counts().plot(kind='bar')
plt.xlabel('Avg VTAT')
plt.ylabel('Count')
plt.title('Bar Plot of Category Counts')
plt.show()

# %%
df['Avg CTAT'].value_counts().plot(kind='bar')
plt.xlabel('Avg CTAT')
plt.ylabel('Count')
plt.title('Bar Plot of Category Counts')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

    

plt.plot(df['Driver Ratings'], df['Customer Rating'])
plt.xlabel('Driver Ratings')
plt.ylabel('Customer Rating')
plt.title('Line Plot of Driver Ratings vs Customer Rating')
plt.show()
